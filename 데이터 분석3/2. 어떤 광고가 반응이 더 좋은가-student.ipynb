# %% [markdown]
# # 어떤 광고가 반응이 더 좋은가?
# #### 게임 개빌회사 A는 지난 문제를 현명하게 해결하고 안정적인 영업을 하고 있으나, 매월 실시하고 있는 게임아이템 판매 이벤트에 대해 고객들의 구매율이 상대적으로 낮음을 확인하였음.
# #### 우리 회사는 맨날 무슨 일이 터지나?
# ![](2-1.jpg)

# %% [markdown]
# #### 유력 가설: 이벤트 공지 및 홍보 활동에 문제가 있다. 구체적으로 우리 게임에 대한 광고 클릭률이 항상 낮다고 한다.
# #### 해결책: 다양한 광고를 조사하고 비교해서 우리 게임 광고 클릭

# %% [markdown]
# ## 1. Loading data

# %% [markdown]
# #### 1) 필요한 라이브러리들을 호출

# %%
#데이터 분석에 필요한 패키지들을 파이썬으로 호출
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chisquare
# %matplotlib inline

# %% [markdown]
# #### 2) 각 변수별로 데이터 할당

# %%
imp = pd.read_csv("ab_test_imp.csv", sep=',')
goal = pd.read_csv("ab_test_goal.csv", sep=',')

# %% [markdown]
# ![](2-2.jpg)

# %% [markdown]
# #### 3) 호출된 데이터 정보 확인

# %%
imp.head()
# Out:
#      log_date app_name   test_name test_case  user_id  transaction_id
# 0  2017-10-01  game-01  sales_test         B    36703           25622
# 1  2017-10-01  game-01  sales_test         A    44339           25623
# 2  2017-10-01  game-01  sales_test         B    32087           25624
# 3  2017-10-01  game-01  sales_test         B    10160           25625
# 4  2017-10-01  game-01  sales_test         B    46113           25626

# %%
goal.head()
# Out:
#      log_date app_name   test_name test_case  user_id  transaction_id
# 0  2017-10-01  game-01  sales_test         B    15021           25638
# 1  2017-10-01  game-01  sales_test         B      351           25704
# 2  2017-10-01  game-01  sales_test         B     8276           25739
# 3  2017-10-01  game-01  sales_test         B     1230           25742
# 4  2017-10-01  game-01  sales_test         B    17471           25743

# %% [markdown]
# # 2. Data cleaning

# %% [markdown]
# #### 1) 각 데이터들을 결합

# %%
#두 데이터 결합하기 
ImpGoal = imp.merge(goal, on=['transaction_id'],how="outer")
ImpGoal.head(20)
# Out:
#     log_date_x app_name_x test_name_x test_case_x  user_id_x  transaction_id  \
# 0   2017-10-01    game-01  sales_test           B    36703.0           25622
# 1   2017-10-01    game-01  sales_test           A    44339.0           25623
# 2   2017-10-01    game-01  sales_test           B    32087.0           25624
# 3   2017-10-01    game-01  sales_test           B    10160.0           25625
# 4   2017-10-01    game-01  sales_test           B    46113.0           25626
# 5   2017-10-01    game-01  sales_test           A     6605.0           25627
# 6   2017-10-01    game-01  sales_test           A      346.0           25628
# 7   2017-10-01    game-01  sales_test           A    42710.0           25629
# 8   2017-10-01    game-01  sales_test           A    37194.0           25630
# 9   2017-10-01    game-01  sales_test           A      123.0           25631
# 10  2017-10-01    game-01  sales_test           A    41638.0           25632
# 11  2017-10-01    game-01  sales_test           B    49024.0           25633
# 12  2017-10-01    game-01  sales_test           B    42199.0           25634
# 13  2017-10-01    game-01  sales_test           B    33444.0           25635
# 14  2017-10-01    game-01  sales_test           B     9347.0           25636
# 15  2017-10-01    game-01  sales_test           B    39412.0           25637
# 16  2017-10-01    game-01  sales_test           B    15021.0           25638
# 17  2017-10-01    game-01  sales_test           B      118.0           25639
# 18  2017-10-01    game-01  sales_test           A    42885.0           25640
# 19  2017-10-01    game-01  sales_test           B     9498.0           25641
#
#     log_date_y app_name_y test_name_y test_case_y  user_id_y
# 0          NaN        NaN         NaN         NaN        NaN
# 1          NaN        NaN         NaN         NaN        NaN
# 2          NaN        NaN         NaN         NaN        NaN
# 3          NaN        NaN         NaN         NaN        NaN
# 4          NaN        NaN         NaN         NaN        NaN
# 5          NaN        NaN         NaN         NaN        NaN
# 6          NaN        NaN         NaN         NaN        NaN
# 7          NaN        NaN         NaN         NaN        NaN
# 8          NaN        NaN         NaN         NaN        NaN
# 9          NaN        NaN         NaN         NaN        NaN
# 10         NaN        NaN         NaN         NaN        NaN
# 11         NaN        NaN         NaN         NaN        NaN
# 12         NaN        NaN         NaN         NaN        NaN
# 13         NaN        NaN         NaN         NaN        NaN
# 14         NaN        NaN         NaN         NaN        NaN
# 15         NaN        NaN         NaN         NaN        NaN
# 16  2017-10-01    game-01  sales_test           B    15021.0
# 17         NaN        NaN         NaN         NaN        NaN
# 18         NaN        NaN         NaN         NaN        NaN
# 19         NaN        NaN         NaN         NaN        NaN

# %% [markdown]
# #### 2) 일자별 정렬을 위한 날짜 처리

# %%
# ImpGoal 데이터프레임 내 "log_date_x"시리즈를 datetime 유형으로 변경
ImpGoal['log_date_x'] = ImpGoal['log_date_x'].apply(lambda x: pd.to_datetime(str(x)))

# %% [markdown]
# #### 3) 광고별 클릭률 지표 설정

# %%
#"is.goal" 시리즈를 만들고 "user_id_y"값이 "true"이면 0, 그렇지 않으면 1으로 표시
ImpGoal['is_Goal'] = np.where(pd.isnull(ImpGoal["user_id_y"]) == True,0,1)

# %%
ImpGoal.head()
# Out:
#    log_date_x app_name_x test_name_x test_case_x  user_id_x  transaction_id  \
# 0  2017-10-01    game-01  sales_test           B    36703.0           25622
# 1  2017-10-01    game-01  sales_test           A    44339.0           25623
# 2  2017-10-01    game-01  sales_test           B    32087.0           25624
# 3  2017-10-01    game-01  sales_test           B    10160.0           25625
# 4  2017-10-01    game-01  sales_test           B    46113.0           25626
#
#   log_date_y app_name_y test_name_y test_case_y  user_id_y  is_Goal
# 0        NaN        NaN         NaN         NaN        NaN        0
# 1        NaN        NaN         NaN         NaN        NaN        0
# 2        NaN        NaN         NaN         NaN        NaN        0
# 3        NaN        NaN         NaN         NaN        NaN        0
# 4        NaN        NaN         NaN         NaN        NaN        0

# %% [markdown]
# # 3. Data analysis

# %% [markdown]
# #### 1) 광고별 클릭률 확인

# %%
# 광고A와 광고B의 각 클릭률 비교
ImpGoal['is_Goal'].groupby(ImpGoal['test_case_x']).mean()
# Out:
# test_case_x
# A    0.080256
# B    0.115392
# Name: is_Goal, dtype: float64

# %% [markdown]
# #### 2) 각 광고별 클릭률 트렌드 확인

# %%
#"log_date_x" 기준에 따라 각 광고별 클릭률을 정렬
data = ImpGoal.groupby(["log_date_x","test_case_x"])['is_Goal'].mean()
data
# Out:
# log_date_x  test_case_x
# 2017-10-01  A              0.072165
#             B              0.126528
# 2017-10-02  A              0.064234
#             B              0.159040
# 2017-10-03  A              0.140148
#             B              0.150041
# 2017-10-04  A              0.058514
#             B              0.119015
# 2017-10-05  A              0.035287
#             B              0.065637
# 2017-10-06  A              0.098441
#             B              0.126023
# 2017-10-07  A              0.121630
#             B              0.113427
# 2017-10-08  A              0.070664
#             B              0.121010
# 2017-10-09  A              0.120752
#             B              0.093365
# 2017-10-10  A              0.083578
#             B              0.072165
# 2017-10-11  A              0.044737
#             B              0.062419
# 2017-10-12  A              0.038102
#             B              0.105190
# 2017-10-13  A              0.098039
#             B              0.147863
# 2017-10-14  A              0.051310
#             B              0.087852
# 2017-10-15  A              0.106353
#             B              0.055434
#                              ...
# 2017-10-17  A              0.045493
#             B              0.114644
# 2017-10-18  A              0.059413
#             B              0.127820
# 2017-10-19  A              0.109405
#             B              0.140541
# 2017-10-20  A              0.081325
#             B              0.171216
# 2017-10-21  A              0.129488
#             B              0.099062
# 2017-10-22  A              0.039589
#             B              0.101429
# 2017-10-23  A              0.146840
#             B              0.149216
# 2017-10-24  A              0.093660
#             B              0.127068
# 2017-10-25  A              0.093192
#             B              0.137639
# 2017-10-26  A              0.109375
#             B              0.135811
# 2017-10-27  A              0.013400
#             B              0.115622
# 2017-10-28  A              0.064151
#             B              0.084756
# 2017-10-29  A              0.058005
#             B              0.106383
# 2017-10-30  A              0.077181
#             B              0.163851
# 2017-10-31  A              0.047970
#             B              0.162037
# Name: is_Goal, Length: 62, dtype: float64

# %% [markdown]
# # 4. Data Visualization

# %% [markdown]
# #### 1) 각 광고별 클릭률 트렌드 시각화

# %%
# unstack()함수를 이용해 완전한 데이터 정규화 수행
data = data.unstack('test_case_x')

# %%
data.head()
# Out:
# test_case_x  log_date_x
# A            2017-10-01    0.072165
#              2017-10-02    0.064234
#              2017-10-03    0.140148
#              2017-10-04    0.058514
#              2017-10-05    0.035287
# dtype: float64

# %%
#완성된 데이터를 이용해 시각화 수행
data.plot.line(figsize=(15,7),style='--',
marker='o',markersize=10,linewidth=2)
